# %%
# Do all imports and installs here - Done
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.functions import udf
import pandas as pd
import re
import configparser
import os
import shutil
from pyspark.sql.types import StructType as R, StructField as Fld,\
    DoubleType as Dbl, StringType as Str, IntegerType as Int,\
    TimestampType as Timestamp, DateType as Date, LongType as Long
from pathlib import Path

# %%
# Run on production version
spark = SparkSession.builder\
            .config("spark.jars.repositories", "https://repos.spark-packages.org/")\
            .config("spark.jars.packages", "saurfang:spark-sas7bdat:2.0.0-s_2.11")\
            .enableHiveSupport()\
            .getOrCreate()

# %% [markdown]
# ### Extracts validation pair values from SAS Labels Description

# %%
def get_validation_code_from_SAS_labels(sas_input_label):
    '''
    This procedure read a input SAS Labels Description and then write out validation code datasets.
    The SAS Labels Description included validation code datasets with labels: I94RES (same to I94CIT), I94PORT, I94ADDR, I94MODE, I94VISA.
    
    Parameters
    ----------
    sas_input_label : string
        The label name of validation code dataset. Its can be one of I94RES (same to I94CIT), I94PORT, I94ADDR, I94MODE, I94VISA.
    
    Returns
    -------
    validation_code_list : validation_value_pairs(tuple(str_valid_code, str_valid_value))
        The return output is a specific SAS label list of validation code value pairs.
    '''

    # Read input SAS Labels Descriptions
    with open('I94_SAS_Labels_Descriptions.SAS') as sas_validation_code:
            labels_from_sas = sas_validation_code.read()

    # Parse labels from SAS Label Description input
    sas_labels = labels_from_sas[labels_from_sas.index(sas_input_label):]
    sas_labels = sas_labels[:sas_labels.index(';')]
    
    # Processing line by line, remove separate charaters and then append value pair
    lines = sas_labels.splitlines()
    validation_code_list = []
    for line in lines:
        try:
            valid_code, valid_value = line.split('=')
            valid_code = valid_code.strip().strip("'").strip('"')
            valid_value = valid_value.strip().strip("'").strip('"').strip()
            validation_code_list.append((valid_code, valid_value))
        except:
            pass
        
    return validation_code_list

# %%
def rmdir(directory):
    '''
    This procedure perform pure recursive a directory.
    
    Parameters
    ----------
    directory : string_of_path_to_dir
        The input directory is a path to target dir. This dir and all its belong child objects wil be deleted.
        Syntax note: rmdir(Path("target_path_to_dir"))
            with Path("target_path_to_dir") returns path to dir format as 'directory' input
    
    Returns
    -------
    None
    '''
    directory = Path(directory)
    for item in directory.iterdir():
        if item.is_dir():
            rmdir(item)
        else:
            item.unlink()
    directory.rmdir()

# %%
def extract_staging_sas_label(label):
    '''
    asdjhkjf.
    
    Parameters
    ----------
    label: 
        a string input of specific label from "SAS_Label_Descriptions.SAS"
        
    Syntax note: 
        input value in string datatype, need inside a pair of single quotes. Ex: 'I94RES', 'I94PORTS'
    
    Returns
    -------
    Dataframe of input label.
    '''
    label_name = label
    valid_code = label + "_valid_code"
    valid_value = label + "_valid_value"
    csv_output = label + "_sas_label_validation"

    schema = R([
        Fld(valid_code, Str()),
        Fld(valid_value, Str())
    ])

    df = spark.createDataFrame(
        data=get_validation_code_from_SAS_labels(label_name),
        schema=schema
    )

    # rmdir(Path(csv_output))
    shutil.rmtree(csv_output, ignore_errors=False, onerror=None)
    df.write.options(header='True', delimiter=',', mode='overwrite').csv(csv_output)
    # df.write.mode('overwrite').csv(csv_output)

    df = spark.read.options(inferSchema="true", delimiter=",", header = "true").csv(csv_output)

    print("Top 20 rows of {} ".format(csv_output))
    df.show()

    print("Count rows of {}: {} ".format(csv_output, df.count()))
    
    print("Check unique value of {}: {} ".format(csv_output, df.select(valid_code).distinct().count()))

    print("Staging csv files in: {}".format(csv_output))

    return df

# %% [markdown]
# ### `I94RES` label - Extract and staging validation values from 'SAS_Labels_Descriptions.SAS'

# %%
I94RES_df = extract_staging_sas_label('I94RES')
# Out:
# Top 20 rows of I94RES_sas_label_validation
# +-----------------+--------------------+
# |I94RES_valid_code|  I94RES_valid_value|
# +-----------------+--------------------+
# |              527|TURKS AND CAICOS ...|
# |              420|              TUVALU|
# |              352|              UGANDA|
# |              162|             UKRAINE|
# |              296|UNITED ARAB EMIRATES|
# |              135|      UNITED KINGDOM|
# |              695|             URUGUAY|
# |              163|          UZBEKISTAN|
# |              410|             VANUATU|
# |              696|           VENEZUELA|
# |              266|             VIETNAM|
# |              469|WALLIS AND FUTUNA...|
# |              757|WEST INDIES (FRENCH)|
# |              333|      WESTERN SAHARA|
# |              465|       WESTERN SAMOA|
# |              216|               YEMEN|
# |              139|          YUGOSLAVIA|
# |              301|               ZAIRE|
# |              344|              ZAMBIA|
# |              315|            ZIMBABWE|
# +-----------------+--------------------+
# only showing top 20 rows
#
# Count rows of I94RES_sas_label_validation: 289
# Check unique value of I94RES_sas_label_validation: 289
# Staging csv files in: I94RES_sas_label_validation

# %%
I94RES_df.select('i94res_valid_code').distinct().collect()
# Out:
# [Row(i94res_valid_code=471),
#  Row(i94res_valid_code=737),
#  Row(i94res_valid_code=296),
#  Row(i94res_valid_code=300),
#  Row(i94res_valid_code=731),
#  Row(i94res_valid_code=914),
#  Row(i94res_valid_code=501),
#  Row(i94res_valid_code=333),
#  Row(i94res_valid_code=319),
#  Row(i94res_valid_code=190),
#  Row(i94res_valid_code=696),
#  Row(i94res_valid_code=139),
#  Row(i94res_valid_code=944),
#  Row(i94res_valid_code=54),
#  Row(i94res_valid_code=266),
#  Row(i94res_valid_code=163),
#  Row(i94res_valid_code=849),
#  Row(i94res_valid_code=505),
#  Row(i94res_valid_code=695),
#  Row(i94res_valid_code=583),
#  Row(i94res_valid_code=503),
#  Row(i94res_valid_code=739),
#  Row(i94res_valid_code=485),
#  Row(i94res_valid_code=301),
#  Row(i94res_valid_code=757),
#  Row(i94res_valid_code=100),
#  Row(i94res_valid_code=719),
#  Row(i94res_valid_code=791),
#  Row(i94res_valid_code=162),
#  Row(i94res_valid_code=238),
#  Row(i94res_valid_code=720),
#  Row(i94res_valid_code=465),
#  Row(i94res_valid_code=277),
#  Row(i94res_valid_code=400),
#  Row(i94res_valid_code=239),
#  Row(i94res_valid_code=403),
#  Row(i94res_valid_code=395),
#  Row(i94res_valid_code=589),
#  Row(i94res_valid_code=527),
#  Row(i94res_valid_code=404),
#  Row(i94res_valid_code=293),
#  Row(i94res_valid_code=216),
#  Row(i94res_valid_code=394),
#  Row(i94res_valid_code=730),
#  Row(i94res_valid_code=219),
#  Row(i94res_valid_code=740),
#  Row(i94res_valid_code=741),
#  Row(i94res_valid_code=710),
#  Row(i94res_valid_code=352),
#  Row(i94res_valid_code=469),
#  Row(i94res_valid_code=712),
#  Row(i94res_valid_code=592),
#  Row(i94res_valid_code=200),
#  Row(i94res_valid_code=574),
#  Row(i94res_valid_code=753),
#  Row(i94res_valid_code=106),
#  Row(i94res_valid_code=344),
#  Row(i94res_valid_code=135),
#  Row(i94res_valid_code=506),
#  Row(i94res_valid_code=999),
#  Row(i94res_valid_code=365),
#  Row(i94res_valid_code=700),
#  Row(i94res_valid_code=311),
#  Row(i94res_valid_code=410),
#  Row(i94res_valid_code=996),
#  Row(i94res_valid_code=420),
#  Row(i94res_valid_code=705),
#  Row(i94res_valid_code=0),
#  Row(i94res_valid_code=755),
#  Row(i94res_valid_code=134),
#  Row(i94res_valid_code=407),
#  Row(i94res_valid_code=315),
#  Row(i94res_valid_code=187),
#  Row(i94res_valid_code=243),
#  Row(i94res_valid_code=513),
#  Row(i94res_valid_code=322),
#  Row(i94res_valid_code=375),
#  Row(i94res_valid_code=108),
#  Row(i94res_valid_code=368),
#  Row(i94res_valid_code=101),
#  Row(i94res_valid_code=385),
#  Row(i94res_valid_code=688),
#  Row(i94res_valid_code=723),
#  Row(i94res_valid_code=384),
#  Row(i94res_valid_code=271),
#  Row(i94res_valid_code=236),
#  Row(i94res_valid_code=103),
#  Row(i94res_valid_code=336),
#  Row(i94res_valid_code=601),
#  Row(i94res_valid_code=372),
#  Row(i94res_valid_code=604),
#  Row(i94res_valid_code=519),
#  Row(i94res_valid_code=111),
#  Row(i94res_valid_code=140),
#  Row(i94res_valid_code=152),
#  Row(i94res_valid_code=386),
#  Row(i94res_valid_code=581),
#  Row(i94res_valid_code=512),
#  Row(i94res_valid_code=274),
#  Row(i94res_valid_code=689),
#  Row(i94res_valid_code=218),
#  Row(i94res_valid_code=164),
#  Row(i94res_valid_code=692),
#  Row(i94res_valid_code=582),
#  Row(i94res_valid_code=165),
#  Row(i94res_valid_code=383),
#  Row(i94res_valid_code=316),
#  Row(i94res_valid_code=324),
#  Row(i94res_valid_code=721),
#  Row(i94res_valid_code=310),
#  Row(i94res_valid_code=217),
#  Row(i94res_valid_code=326),
#  Row(i94res_valid_code=717),
#  Row(i94res_valid_code=687),
#  Row(i94res_valid_code=691),
#  Row(i94res_valid_code=585),
#  Row(i94res_valid_code=532),
#  Row(i94res_valid_code=438),
#  Row(i94res_valid_code=467),
#  Row(i94res_valid_code=509),
#  Row(i94res_valid_code=102),
#  Row(i94res_valid_code=518),
#  Row(i94res_valid_code=576),
#  Row(i94res_valid_code=240),
#  Row(i94res_valid_code=245),
#  Row(i94res_valid_code=526),
#  Row(i94res_valid_code=151),
#  Row(i94res_valid_code=109),
#  Row(i94res_valid_code=298),
#  Row(i94res_valid_code=105),
#  Row(i94res_valid_code=575),
#  Row(i94res_valid_code=369),
#  Row(i94res_valid_code=413),
#  Row(i94res_valid_code=110),
#  Row(i94res_valid_code=525),
#  Row(i94res_valid_code=317),
#  Row(i94res_valid_code=242),
#  Row(i94res_valid_code=690),
#  Row(i94res_valid_code=270),
#  Row(i94res_valid_code=529),
#  Row(i94res_valid_code=399),
#  Row(i94res_valid_code=153),
#  Row(i94res_valid_code=104),
#  Row(i94res_valid_code=584),
#  Row(i94res_valid_code=393),
#  Row(i94res_valid_code=516),
#  Row(i94res_valid_code=321),
#  Row(i94res_valid_code=126),
#  Row(i94res_valid_code=412),
#  Row(i94res_valid_code=743),
#  Row(i94res_valid_code=159),
#  Row(i94res_valid_code=350),
#  Row(i94res_valid_code=602),
#  Row(i94res_valid_code=417),
#  Row(i94res_valid_code=409),
#  Row(i94res_valid_code=128),
#  Row(i94res_valid_code=330),
#  Row(i94res_valid_code=346),
#  Row(i94res_valid_code=416),
#  Row(i94res_valid_code=694),
#  Row(i94res_valid_code=353),
#  Row(i94res_valid_code=748),
#  Row(i94res_valid_code=297),
#  Row(i94res_valid_code=440),
#  Row(i94res_valid_code=348),
#  Row(i94res_valid_code=474),
#  Row(i94res_valid_code=142),
#  Row(i94res_valid_code=470),
#  Row(i94res_valid_code=268),
#  Row(i94res_valid_code=258),
#  Row(i94res_valid_code=397),
#  Row(i94res_valid_code=257),
#  Row(i94res_valid_code=579),
#  Row(i94res_valid_code=504),
#  Row(i94res_valid_code=347),
#  Row(i94res_valid_code=262),
#  Row(i94res_valid_code=207),
#  Row(i94res_valid_code=127),
#  Row(i94res_valid_code=523),
#  Row(i94res_valid_code=502),
#  Row(i94res_valid_code=107),
#  Row(i94res_valid_code=263),
#  Row(i94res_valid_code=441),
#  Row(i94res_valid_code=161),
#  Row(i94res_valid_code=736),
#  Row(i94res_valid_code=244),
#  Row(i94res_valid_code=130),
#  Row(i94res_valid_code=343),
#  Row(i94res_valid_code=391),
#  Row(i94res_valid_code=166),
#  Row(i94res_valid_code=129),
#  Row(i94res_valid_code=693),
#  Row(i94res_valid_code=524),
#  Row(i94res_valid_code=264),
#  Row(i94res_valid_code=261),
#  Row(i94res_valid_code=351),
#  Row(i94res_valid_code=390),
#  Row(i94res_valid_code=464),
#  Row(i94res_valid_code=323),
#  Row(i94res_valid_code=256),
#  Row(i94res_valid_code=371),
#  Row(i94res_valid_code=141),
#  Row(i94res_valid_code=376),
#  Row(i94res_valid_code=749),
#  Row(i94res_valid_code=304),
#  Row(i94res_valid_code=508),
#  Row(i94res_valid_code=260),
#  Row(i94res_valid_code=123),
#  Row(i94res_valid_code=373),
#  Row(i94res_valid_code=158),
#  Row(i94res_valid_code=522),
#  Row(i94res_valid_code=276),
#  Row(i94res_valid_code=131),
#  Row(i94res_valid_code=124),
#  Row(i94res_valid_code=275),
#  Row(i94res_valid_code=716),
#  Row(i94res_valid_code=745),
#  Row(i94res_valid_code=392),
#  Row(i94res_valid_code=251),
#  Row(i94res_valid_code=255),
#  Row(i94res_valid_code=472),
#  Row(i94res_valid_code=155),
#  Row(i94res_valid_code=115),
#  Row(i94res_valid_code=577),
#  Row(i94res_valid_code=332),
#  Row(i94res_valid_code=253),
#  Row(i94res_valid_code=329),
#  Row(i94res_valid_code=388),
#  Row(i94res_valid_code=209),
#  Row(i94res_valid_code=122),
#  Row(i94res_valid_code=758),
#  Row(i94res_valid_code=157),
#  Row(i94res_valid_code=603),
#  Row(i94res_valid_code=473),
#  Row(i94res_valid_code=206),
#  Row(i94res_valid_code=760),
#  Row(i94res_valid_code=340),
#  Row(i94res_valid_code=250),
#  Row(i94res_valid_code=339),
#  Row(i94res_valid_code=120),
#  Row(i94res_valid_code=732),
#  Row(i94res_valid_code=507),
#  Row(i94res_valid_code=729),
#  Row(i94res_valid_code=299),
#  Row(i94res_valid_code=117),
#  Row(i94res_valid_code=154),
#  Row(i94res_valid_code=511),
#  Row(i94res_valid_code=112),
#  Row(i94res_valid_code=327),
#  Row(i94res_valid_code=586),
#  Row(i94res_valid_code=387),
#  Row(i94res_valid_code=381),
#  Row(i94res_valid_code=114),
#  Row(i94res_valid_code=220),
#  Row(i94res_valid_code=520),
#  Row(i94res_valid_code=514),
#  Row(i94res_valid_code=273),
#  Row(i94res_valid_code=389),
#  Row(i94res_valid_code=759),
#  Row(i94res_valid_code=320),
#  Row(i94res_valid_code=249),
#  Row(i94res_valid_code=167),
#  Row(i94res_valid_code=113),
#  Row(i94res_valid_code=121),
#  Row(i94res_valid_code=156),
#  Row(i94res_valid_code=143),
#  Row(i94res_valid_code=411),
#  Row(i94res_valid_code=528),
#  Row(i94res_valid_code=214),
#  Row(i94res_valid_code=338),
#  Row(i94res_valid_code=335),
#  Row(i94res_valid_code=345),
#  Row(i94res_valid_code=382),
#  Row(i94res_valid_code=203),
#  Row(i94res_valid_code=414),
#  Row(i94res_valid_code=272),
#  Row(i94res_valid_code=145),
#  Row(i94res_valid_code=735),
#  Row(i94res_valid_code=213),
#  Row(i94res_valid_code=370),
#  Row(i94res_valid_code=726),
#  Row(i94res_valid_code=204),
#  Row(i94res_valid_code=116),
#  Row(i94res_valid_code=342),
#  Row(i94res_valid_code=119),
#  Row(i94res_valid_code=201),
#  Row(i94res_valid_code=149),
#  Row(i94res_valid_code=118),
#  Row(i94res_valid_code=521)]

# %%
I94RES_df = I94RES_df.withColumn("length", F.length("I94RES_valid_code"))
I94RES_df.printSchema()
I94RES_df.show(truncate=False)
# Out:
# root
#  |-- I94RES_valid_code: integer (nullable = true)
#  |-- I94RES_valid_value: string (nullable = true)
#  |-- length: integer (nullable = true)
#
# +-----------------+-------------------------+------+
# |I94RES_valid_code|I94RES_valid_value       |length|
# +-----------------+-------------------------+------+
# |527              |TURKS AND CAICOS ISLANDS |3     |
# |420              |TUVALU                   |3     |
# |352              |UGANDA                   |3     |
# |162              |UKRAINE                  |3     |
# |296              |UNITED ARAB EMIRATES     |3     |
# |135              |UNITED KINGDOM           |3     |
# |695              |URUGUAY                  |3     |
# |163              |UZBEKISTAN               |3     |
# |410              |VANUATU                  |3     |
# |696              |VENEZUELA                |3     |
# |266              |VIETNAM                  |3     |
# |469              |WALLIS AND FUTUNA ISLANDS|3     |
# |757              |WEST INDIES (FRENCH)     |3     |
# |333              |WESTERN SAHARA           |3     |
# |465              |WESTERN SAMOA            |3     |
# |216              |YEMEN                    |3     |
# |139              |YUGOSLAVIA               |3     |
# |301              |ZAIRE                    |3     |
# |344              |ZAMBIA                   |3     |
# |315              |ZIMBABWE                 |3     |
# +-----------------+-------------------------+------+
# only showing top 20 rows

# %%
I94RES_df.createOrReplaceTempView('i94res_table')

# %%
# Verify created table will be using for staging
spark.sql("""
    SELECT COUNT(*) as amount_i94res_rows
    FROM i94res_table
""").show()
# Out:
# +------------------+
# |amount_i94res_rows|
# +------------------+
# |               289|
# +------------------+

# %% [markdown]
# ### `I94PORT` label - Extract and staging validation values from 'SAS_Labels_Descriptions.SAS'

# %%
I94PORT_df = extract_staging_sas_label('I94PORT')
# Out:
# Top 20 rows of I94PORT_sas_label_validation
# +------------------+--------------------+
# |I94PORT_valid_code| I94PORT_valid_value|
# +------------------+--------------------+
# |               ORO|        OROVILLE, WA|
# |               PWB|           PASCO, WA|
# |               PIR|   POINT ROBERTS, WA|
# |               PNG|    PORT ANGELES, WA|
# |               PTO|   PORT TOWNSEND, WA|
# |               SEA|         SEATTLE, WA|
# |               SPO|         SPOKANE, WA|
# |               SUM|           SUMAS, WA|
# |               TAC|          TACOMA, WA|
# |               PSC|TRI-CITIES - PASC...|
# |               VAN|       VANCOUVER, WA|
# |               AGM|          ALGOMA, WI|
# |               BAY|        BAYFIELD, WI|
# |               GRB|       GREEN BAY, WI|
# |               MNW|       MANITOWOC, WI|
# |               MIL|       MILWAUKEE, WI|
# |               MSN|TRUAX FIELD - DAN...|
# |               CHS|      CHARLESTON, WV|
# |               CLK|      CLARKSBURG, WV|
# |               BLF|   MERCER COUNTY, WV|
# +------------------+--------------------+
# only showing top 20 rows
#
# Count rows of I94PORT_sas_label_validation: 660
# Check unique value of I94PORT_sas_label_validation: 660
# Staging csv files in: I94PORT_sas_label_validation

# %%
I94PORT_df.select('I94PORT_valid_code').distinct().collect()
# Out:
# [Row(I94PORT_valid_code='UIO'),
#  Row(I94PORT_valid_code='FOK'),
#  Row(I94PORT_valid_code='LND'),
#  Row(I94PORT_valid_code='GRB'),
#  Row(I94PORT_valid_code='CLG'),
#  Row(I94PORT_valid_code='ZZZ'),
#  Row(I94PORT_valid_code='NGL'),
#  Row(I94PORT_valid_code='AUH'),
#  Row(I94PORT_valid_code='NAS'),
#  Row(I94PORT_valid_code='RIV'),
#  Row(I94PORT_valid_code='NK'),
#  Row(I94PORT_valid_code='VMB'),
#  Row(I94PORT_valid_code='MSN'),
#  Row(I94PORT_valid_code='MAL'),
#  Row(I94PORT_valid_code='OTT'),
#  Row(I94PORT_valid_code='DRV'),
#  Row(I94PORT_valid_code='CLX'),
#  Row(I94PORT_valid_code='ARB'),
#  Row(I94PORT_valid_code='OSN'),
#  Row(I94PORT_valid_code='GRU'),
#  Row(I94PORT_valid_code='OLM'),
#  Row(I94PORT_valid_code='TAC'),
#  Row(I94PORT_valid_code='BUS'),
#  Row(I94PORT_valid_code='MTH'),
#  Row(I94PORT_valid_code='FOU'),
#  Row(I94PORT_valid_code='IAG'),
#  Row(I94PORT_valid_code='ADU'),
#  Row(I94PORT_valid_code='888'),
#  Row(I94PORT_valid_code='FSC'),
#  Row(I94PORT_valid_code='PTO'),
#  Row(I94PORT_valid_code='VCV'),
#  Row(I94PORT_valid_code='OGS'),
#  Row(I94PORT_valid_code='BHX'),
#  Row(I94PORT_valid_code='JFA'),
#  Row(I94PORT_valid_code='PEK'),
#  Row(I94PORT_valid_code='060'),
#  Row(I94PORT_valid_code='HAM'),
#  Row(I94PORT_valid_code='HAL'),
#  Row(I94PORT_valid_code='SHA'),
#  Row(I94PORT_valid_code='RME'),
#  Row(I94PORT_valid_code='CAK'),
#  Row(I94PORT_valid_code='JSJ'),
#  Row(I94PORT_valid_code='RYY'),
#  Row(I94PORT_valid_code='SCH'),
#  Row(I94PORT_valid_code='VER'),
#  Row(I94PORT_valid_code='VAN'),
#  Row(I94PORT_valid_code='CLK'),
#  Row(I94PORT_valid_code='MNW'),
#  Row(I94PORT_valid_code='74S'),
#  Row(I94PORT_valid_code='BDA'),
#  Row(I94PORT_valid_code='MLI'),
#  Row(I94PORT_valid_code='MEX'),
#  Row(I94PORT_valid_code='ATW'),
#  Row(I94PORT_valid_code='YHC'),
#  Row(I94PORT_valid_code='CRQ'),
#  Row(I94PORT_valid_code='PNG'),
#  Row(I94PORT_valid_code='SRO'),
#  Row(I94PORT_valid_code='X44'),
#  Row(I94PORT_valid_code='AMT'),
#  Row(I94PORT_valid_code='CHS'),
#  Row(I94PORT_valid_code='BEI'),
#  Row(I94PORT_valid_code='HRL'),
#  Row(I94PORT_valid_code='ISP'),
#  Row(I94PORT_valid_code='EZE'),
#  Row(I94PORT_valid_code='CPX'),
#  Row(I94PORT_valid_code='TOR'),
#  Row(I94PORT_valid_code='SP0'),
#  Row(I94PORT_valid_code='AMS'),
#  Row(I94PORT_valid_code='XNA'),
#  Row(I94PORT_valid_code='WTR'),
#  Row(I94PORT_valid_code='T01'),
#  Row(I94PORT_valid_code='BAN'),
#  Row(I94PORT_valid_code='HIL'),
#  Row(I94PORT_valid_code='UNK'),
#  Row(I94PORT_valid_code='EDA'),
#  Row(I94PORT_valid_code='SEA'),
#  Row(I94PORT_valid_code='CXO'),
#  Row(I94PORT_valid_code='NBO'),
#  Row(I94PORT_valid_code='PIR'),
#  Row(I94PORT_valid_code='ICN'),
#  Row(I94PORT_valid_code='YGF'),
#  Row(I94PORT_valid_code='PSC'),
#  Row(I94PORT_valid_code='CUN'),
#  Row(I94PORT_valid_code='Y62'),
#  Row(I94PORT_valid_code='SLP'),
#  Row(I94PORT_valid_code='BAY'),
#  Row(I94PORT_valid_code='TIW'),
#  Row(I94PORT_valid_code='WIN'),
#  Row(I94PORT_valid_code='NYL'),
#  Row(I94PORT_valid_code='XXX'),
#  Row(I94PORT_valid_code='MAR'),
#  Row(I94PORT_valid_code='BKF'),
#  Row(I94PORT_valid_code='DUR'),
#  Row(I94PORT_valid_code='LGW'),
#  Row(I94PORT_valid_code='LHR'),
#  Row(I94PORT_valid_code='BLF'),
#  Row(I94PORT_valid_code='MON'),
#  Row(I94PORT_valid_code='AG'),
#  Row(I94PORT_valid_code='PTY'),
#  Row(I94PORT_valid_code='PLB'),
#  Row(I94PORT_valid_code='LAH'),
#  Row(I94PORT_valid_code='CSP'),
#  Row(I94PORT_valid_code='OAI'),
#  Row(I94PORT_valid_code='NC8'),
#  Row(I94PORT_valid_code='GAC'),
#  Row(I94PORT_valid_code='PWB'),
#  Row(I94PORT_valid_code='EGE'),
#  Row(I94PORT_valid_code='PHN'),
#  Row(I94PORT_valid_code='CNC'),
#  Row(I94PORT_valid_code='BCM'),
#  Row(I94PORT_valid_code='SUM'),
#  Row(I94PORT_valid_code='WA5'),
#  Row(I94PORT_valid_code='BHM'),
#  Row(I94PORT_valid_code='DEC'),
#  Row(I94PORT_valid_code='JBQ'),
#  Row(I94PORT_valid_code='YXE'),
#  Row(I94PORT_valid_code='PHF'),
#  Row(I94PORT_valid_code='DAY'),
#  Row(I94PORT_valid_code='OTS'),
#  Row(I94PORT_valid_code='GPI'),
#  Row(I94PORT_valid_code='MTY'),
#  Row(I94PORT_valid_code='SPO'),
#  Row(I94PORT_valid_code='CP'),
#  Row(I94PORT_valid_code='RIT'),
#  Row(I94PORT_valid_code='STN'),
#  Row(I94PORT_valid_code='FTB'),
#  Row(I94PORT_valid_code='ASI'),
#  Row(I94PORT_valid_code='LIT'),
#  Row(I94PORT_valid_code='ORO'),
#  Row(I94PORT_valid_code='DUB'),
#  Row(I94PORT_valid_code='GMT'),
#  Row(I94PORT_valid_code='PFN'),
#  Row(I94PORT_valid_code='.GA'),
#  Row(I94PORT_valid_code='FRG'),
#  Row(I94PORT_valid_code='JMZ'),
#  Row(I94PORT_valid_code='AKT'),
#  Row(I94PORT_valid_code='HMO'),
#  Row(I94PORT_valid_code='TOK'),
#  Row(I94PORT_valid_code='SPV'),
#  Row(I94PORT_valid_code='PCW'),
#  Row(I94PORT_valid_code='X96'),
#  Row(I94PORT_valid_code='IWA'),
#  Row(I94PORT_valid_code='NCA'),
#  Row(I94PORT_valid_code='FBA'),
#  Row(I94PORT_valid_code='AGM'),
#  Row(I94PORT_valid_code='VIC'),
#  Row(I94PORT_valid_code='MAA'),
#  Row(I94PORT_valid_code='VNY'),
#  Row(I94PORT_valid_code='BOG'),
#  Row(I94PORT_valid_code='YUM'),
#  Row(I94PORT_valid_code='CHN'),
#  Row(I94PORT_valid_code='AG0'),
#  Row(I94PORT_valid_code='GCM'),
#  Row(I94PORT_valid_code='MDE'),
#  Row(I94PORT_valid_code='SAN'),
#  Row(I94PORT_valid_code='SNO'),
#  Row(I94PORT_valid_code='W55'),
#  Row(I94PORT_valid_code='MVD'),
#  Row(I94PORT_valid_code='GDL'),
#  Row(I94PORT_valid_code='5T6'),
#  Row(I94PORT_valid_code='A2A'),
#  Row(I94PORT_valid_code='CND'),
#  Row(I94PORT_valid_code='JIG'),
#  Row(I94PORT_valid_code='MIL'),
#  Row(I94PORT_valid_code='SUS'),
#  Row(I94PORT_valid_code='PSE'),
#  Row(I94PORT_valid_code='MOR'),
#  Row(I94PORT_valid_code='MBO'),
#  Row(I94PORT_valid_code='ENS'),
#  Row(I94PORT_valid_code='SNA'),
#  Row(I94PORT_valid_code='GRR'),
#  Row(I94PORT_valid_code='ABS'),
#  Row(I94PORT_valid_code='EVE'),
#  Row(I94PORT_valid_code='JCP'),
#  Row(I94PORT_valid_code='PVD'),
#  Row(I94PORT_valid_code='MYR'),
#  Row(I94PORT_valid_code='PBB'),
#  Row(I94PORT_valid_code='DAA'),
#  Row(I94PORT_valid_code='SCC'),
#  Row(I94PORT_valid_code='NRN'),
#  Row(I94PORT_valid_code='STA'),
#  Row(I94PORT_valid_code='FAL'),
#  Row(I94PORT_valid_code='BEE'),
#  Row(I94PORT_valid_code='NRT'),
#  Row(I94PORT_valid_code='RDM'),
#  Row(I94PORT_valid_code='NSV'),
#  Row(I94PORT_valid_code='SNN'),
#  Row(I94PORT_valid_code='RIF'),
#  Row(I94PORT_valid_code='AFW'),
#  Row(I94PORT_valid_code='LLB'),
#  Row(I94PORT_valid_code='TRI'),
#  Row(I94PORT_valid_code='AGU'),
#  Row(I94PORT_valid_code='EGP'),
#  Row(I94PORT_valid_code='ROM'),
#  Row(I94PORT_valid_code='ANA'),
#  Row(I94PORT_valid_code='MWH'),
#  Row(I94PORT_valid_code='AST'),
#  Row(I94PORT_valid_code='CHO'),
#  Row(I94PORT_valid_code='WBE'),
#  Row(I94PORT_valid_code='FTH'),
#  Row(I94PORT_valid_code='YOU'),
#  Row(I94PORT_valid_code='FRK'),
#  Row(I94PORT_valid_code='ERI'),
#  Row(I94PORT_valid_code='MRS'),
#  Row(I94PORT_valid_code='CNA'),
#  Row(I94PORT_valid_code='SDY'),
#  Row(I94PORT_valid_code='TOL'),
#  Row(I94PORT_valid_code='HOP'),
#  Row(I94PORT_valid_code='TRO'),
#  Row(I94PORT_valid_code='ERC'),
#  Row(I94PORT_valid_code='HPN'),
#  Row(I94PORT_valid_code='AUS'),
#  Row(I94PORT_valid_code='SGR'),
#  Row(I94PORT_valid_code='PHR'),
#  Row(I94PORT_valid_code='HEF'),
#  Row(I94PORT_valid_code='PAR'),
#  Row(I94PORT_valid_code='DLV'),
#  Row(I94PORT_valid_code='FAB'),
#  Row(I94PORT_valid_code='MCA'),
#  Row(I94PORT_valid_code='NIG'),
#  Row(I94PORT_valid_code='TUL'),
#  Row(I94PORT_valid_code='HUM'),
#  Row(I94PORT_valid_code='PGR'),
#  Row(I94PORT_valid_code='RCM'),
#  Row(I94PORT_valid_code='FAJ'),
#  Row(I94PORT_valid_code='MAF'),
#  Row(I94PORT_valid_code='NOR'),
#  Row(I94PORT_valid_code='FPT'),
#  Row(I94PORT_valid_code='GAL'),
#  Row(I94PORT_valid_code='VIB'),
#  Row(I94PORT_valid_code='BWA'),
#  Row(I94PORT_valid_code='LOI'),
#  Row(I94PORT_valid_code='ABG'),
#  Row(I94PORT_valid_code='CUR'),
#  Row(I94PORT_valid_code='AKR'),
#  Row(I94PORT_valid_code='LOR'),
#  Row(I94PORT_valid_code='VQS'),
#  Row(I94PORT_valid_code='LAR'),
#  Row(I94PORT_valid_code='CLM'),
#  Row(I94PORT_valid_code='BRO'),
#  Row(I94PORT_valid_code='POE'),
#  Row(I94PORT_valid_code='ATB'),
#  Row(I94PORT_valid_code='SAJ'),
#  Row(I94PORT_valid_code='KLM'),
#  Row(I94PORT_valid_code='PIV'),
#  Row(I94PORT_valid_code='CIN'),
#  Row(I94PORT_valid_code='BOA'),
#  Row(I94PORT_valid_code='HSB'),
#  Row(I94PORT_valid_code='LCB'),
#  Row(I94PORT_valid_code='ADS'),
#  Row(I94PORT_valid_code='BLI'),
#  Row(I94PORT_valid_code='NEA'),
#  Row(I94PORT_valid_code='JOB'),
#  Row(I94PORT_valid_code='SPF'),
#  Row(I94PORT_valid_code='DAL'),
#  Row(I94PORT_valid_code='CLE'),
#  Row(I94PORT_valid_code='PUT'),
#  Row(I94PORT_valid_code='GEO'),
#  Row(I94PORT_valid_code='THO'),
#  Row(I94PORT_valid_code='OKC'),
#  Row(I94PORT_valid_code='ELM'),
#  Row(I94PORT_valid_code='SWB'),
#  Row(I94PORT_valid_code='HIO'),
#  Row(I94PORT_valid_code='DVL'),
#  Row(I94PORT_valid_code='NPT'),
#  Row(I94PORT_valid_code='ABE'),
#  Row(I94PORT_valid_code='GSP'),
#  Row(I94PORT_valid_code='DNA'),
#  Row(I94PORT_valid_code='LSE'),
#  Row(I94PORT_valid_code='NWN'),
#  Row(I94PORT_valid_code='LON'),
#  Row(I94PORT_valid_code='CRP'),
#  Row(I94PORT_valid_code='LRN'),
#  Row(I94PORT_valid_code='NPV'),
#  Row(I94PORT_valid_code='SWF'),
#  Row(I94PORT_valid_code='CRU'),
#  Row(I94PORT_valid_code='MED'),
#  Row(I94PORT_valid_code='POO'),
#  Row(I94PORT_valid_code='CHL'),
#  Row(I94PORT_valid_code='MEM'),
#  Row(I94PORT_valid_code='BTC'),
#  Row(I94PORT_valid_code='ELP'),
#  Row(I94PORT_valid_code='ROU'),
#  Row(I94PORT_valid_code='PHI'),
#  Row(I94PORT_valid_code='PRO'),
#  Row(I94PORT_valid_code='DLR'),
#  Row(I94PORT_valid_code='LGU'),
#  Row(I94PORT_valid_code='CAE'),
#  Row(I94PORT_valid_code='YSL'),
#  Row(I94PORT_valid_code='ISB'),
#  Row(I94PORT_valid_code='LAU'),
#  Row(I94PORT_valid_code='WAT'),
#  Row(I94PORT_valid_code='BEA'),
#  Row(I94PORT_valid_code='BQN'),
#  Row(I94PORT_valid_code='RIO'),
#  Row(I94PORT_valid_code='SYR'),
#  Row(I94PORT_valid_code='BRG'),
#  Row(I94PORT_valid_code='FRI'),
#  Row(I94PORT_valid_code='PIT'),
#  Row(I94PORT_valid_code='PON'),
#  Row(I94PORT_valid_code='HID'),
#  Row(I94PORT_valid_code='ADT'),
#  Row(I94PORT_valid_code='BBP'),
#  Row(I94PORT_valid_code='OLY'),
#  Row(I94PORT_valid_code='HIG'),
#  Row(I94PORT_valid_code='MET'),
#  Row(I94PORT_valid_code='IND'),
#  Row(I94PORT_valid_code='CHR'),
#  Row(I94PORT_valid_code='DER'),
#  Row(I94PORT_valid_code='HLG'),
#  Row(I94PORT_valid_code='HON'),
#  Row(I94PORT_valid_code='PDN'),
#  Row(I94PORT_valid_code='TYS'),
#  Row(I94PORT_valid_code='HOU'),
#  Row(I94PORT_valid_code='CHA'),
#  Row(I94PORT_valid_code='COO'),
#  Row(I94PORT_valid_code='BEL'),
#  Row(I94PORT_valid_code='MDT'),
#  Row(I94PORT_valid_code='FWA'),
#  Row(I94PORT_valid_code='ANZ'),
#  Row(I94PORT_valid_code='BLA'),
#  Row(I94PORT_valid_code='ROC'),
#  Row(I94PORT_valid_code='PRE'),
#  Row(I94PORT_valid_code='FER'),
#  Row(I94PORT_valid_code='WRB'),
#  Row(I94PORT_valid_code='MAY'),
#  Row(I94PORT_valid_code='BEB'),
#  Row(I94PORT_valid_code='SLC'),
#  Row(I94PORT_valid_code='STT'),
#  Row(I94PORT_valid_code='SAI'),
#  Row(I94PORT_valid_code='FMY'),
#  Row(I94PORT_valid_code='BGM'),
#  Row(I94PORT_valid_code='EGL'),
#  Row(I94PORT_valid_code='FRN'),
#  Row(I94PORT_valid_code='BUR'),
#  Row(I94PORT_valid_code='OPF'),
#  Row(I94PORT_valid_code='HOM'),
#  Row(I94PORT_valid_code='IDA'),
#  Row(I94PORT_valid_code='SPC'),
#  Row(I94PORT_valid_code='SNP'),
#  Row(I94PORT_valid_code='OAK'),
#  Row(I94PORT_valid_code='RFD'),
#  Row(I94PORT_valid_code='CID'),
#  Row(I94PORT_valid_code='MLU'),
#  Row(I94PORT_valid_code='HUR'),
#  Row(I94PORT_valid_code='AGA'),
#  Row(I94PORT_valid_code='OTM'),
#  Row(I94PORT_valid_code='PKC'),
#  Row(I94PORT_valid_code='BWM'),
#  Row(I94PORT_valid_code='LEX'),
#  Row(I94PORT_valid_code='NOM'),
#  Row(I94PORT_valid_code='SFR'),
#  Row(I94PORT_valid_code='ADW'),
#  Row(I94PORT_valid_code='COB'),
#  Row(I94PORT_valid_code='SAV'),
#  Row(I94PORT_valid_code='HAR'),
#  Row(I94PORT_valid_code='DVD'),
#  Row(I94PORT_valid_code='LYN'),
#  Row(I94PORT_valid_code='BED'),
#  Row(I94PORT_valid_code='NOG'),
#  Row(I94PORT_valid_code='MOB'),
#  Row(I94PORT_valid_code='NWH'),
#  Row(I94PORT_valid_code='LAK'),
#  Row(I94PORT_valid_code='WRA'),
#  Row(I94PORT_valid_code='TUC'),
#  Row(I94PORT_valid_code='LIH'),
#  Row(I94PORT_valid_code='BAL'),
#  Row(I94PORT_valid_code='PTL'),
#  Row(I94PORT_valid_code='FTF'),
#  Row(I94PORT_valid_code='ORI'),
#  Row(I94PORT_valid_code='BFL'),
#  Row(I94PORT_valid_code='SLO'),
#  Row(I94PORT_valid_code='WLL'),
#  Row(I94PORT_valid_code='SRQ'),
#  Row(I94PORT_valid_code='FRB'),
#  Row(I94PORT_valid_code='SBN'),
#  Row(I94PORT_valid_code='ALC'),
#  Row(I94PORT_valid_code='LNB'),
#  Row(I94PORT_valid_code='INP'),
#  Row(I94PORT_valid_code='NOL'),
#  Row(I94PORT_valid_code='BGC'),
#  Row(I94PORT_valid_code='SLS'),
#  Row(I94PORT_valid_code='JAC'),
#  Row(I94PORT_valid_code='TRV'),
#  Row(I94PORT_valid_code='YUI'),
#  Row(I94PORT_valid_code='BOS'),
#  Row(I94PORT_valid_code='EPT'),
#  Row(I94PORT_valid_code='MLB'),
#  Row(I94PORT_valid_code='ROG'),
#  Row(I94PORT_valid_code='MRL'),
#  Row(I94PORT_valid_code='5KE'),
#  Row(I94PORT_valid_code='GLO'),
#  Row(I94PORT_valid_code='BRU'),
#  Row(I94PORT_valid_code='DTH'),
#  Row(I94PORT_valid_code='DPA'),
#  Row(I94PORT_valid_code='MGC'),
#  Row(I94PORT_valid_code='SAS'),
#  Row(I94PORT_valid_code='SAU'),
#  Row(I94PORT_valid_code='POR'),
#  Row(I94PORT_valid_code='DEN'),
#  Row(I94PORT_valid_code='PEN'),
#  Row(I94PORT_valid_code='PSP'),
#  Row(I94PORT_valid_code='SGJ'),
#  Row(I94PORT_valid_code='BOI'),
#  Row(I94PORT_valid_code='SLU'),
#  Row(I94PORT_valid_code='DRO'),
#  Row(I94PORT_valid_code='LIA'),
#  Row(I94PORT_valid_code='FRE'),
#  Row(I94PORT_valid_code='KET'),
#  Row(I94PORT_valid_code='AND'),
#  Row(I94PORT_valid_code='SPE'),
#  Row(I94PORT_valid_code='BOC'),
#  Row(I94PORT_valid_code='HMM'),
#  Row(I94PORT_valid_code='BDL'),
#  Row(I94PORT_valid_code='APF'),
#  Row(I94PORT_valid_code='MIA'),
#  Row(I94PORT_valid_code='PSJ'),
#  Row(I94PORT_valid_code='DOU'),
#  Row(I94PORT_valid_code='PAN'),
#  Row(I94PORT_valid_code='SPI'),
#  Row(I94PORT_valid_code='UGN'),
#  Row(I94PORT_valid_code='DAC'),
#  Row(I94PORT_valid_code='SFB'),
#  Row(I94PORT_valid_code='APA'),
#  Row(I94PORT_valid_code='PHO'),
#  Row(I94PORT_valid_code='CAL'),
#  Row(I94PORT_valid_code='HHW'),
#  Row(I94PORT_valid_code='BTN'),
#  Row(I94PORT_valid_code='FTL'),
#  Row(I94PORT_valid_code='ICP'),
#  Row(I94PORT_valid_code='SAA'),
#  Row(I94PORT_valid_code='STO'),
#  Row(I94PORT_valid_code='LUK'),
#  Row(I94PORT_valid_code='PCF'),
#  Row(I94PORT_valid_code='TAM'),
#  Row(I94PORT_valid_code='BCK'),
#  Row(I94PORT_valid_code='SDP'),
#  Row(I94PORT_valid_code='GAR'),
#  Row(I94PORT_valid_code='LKC'),
#  Row(I94PORT_valid_code='CLS'),
#  Row(I94PORT_valid_code='MOS'),
#  Row(I94PORT_valid_code='CAN'),
#  Row(I94PORT_valid_code='KEY'),
#  Row(I94PORT_valid_code='SAC'),
#  Row(I94PORT_valid_code='SYS'),
#  Row(I94PORT_valid_code='ATL'),
#  Row(I94PORT_valid_code='BOO'),
#  Row(I94PORT_valid_code='PIZ'),
#  Row(I94PORT_valid_code='HYD'),
#  Row(I94PORT_valid_code='EPM'),
#  Row(I94PORT_valid_code='BAR'),
#  Row(I94PORT_valid_code='WAS'),
#  Row(I94PORT_valid_code='PEV'),
#  Row(I94PORT_valid_code='TKI'),
#  Row(I94PORT_valid_code='EST'),
#  Row(I94PORT_valid_code='TEC'),
#  Row(I94PORT_valid_code='ICT'),
#  Row(I94PORT_valid_code='NIK'),
#  Row(I94PORT_valid_code='JUN'),
#  Row(I94PORT_valid_code='CAO'),
#  Row(I94PORT_valid_code='MKG'),
#  Row(I94PORT_valid_code='CRB'),
#  Row(I94PORT_valid_code='PIA'),
#  Row(I94PORT_valid_code='GRT'),
#  Row(I94PORT_valid_code='WPB'),
#  Row(I94PORT_valid_code='SKA'),
#  Row(I94PORT_valid_code='BLT'),
#  Row(I94PORT_valid_code='NAC'),
#  Row(I94PORT_valid_code='HSV'),
#  Row(I94PORT_valid_code='NWL'),
#  Row(I94PORT_valid_code='PAX'),
#  Row(I94PORT_valid_code='LOS'),
#  Row(I94PORT_valid_code='COS'),
#  Row(I94PORT_valid_code='TST'),
#  Row(I94PORT_valid_code='LOU'),
#  Row(I94PORT_valid_code='KOA'),
#  Row(I94PORT_valid_code='FPF'),
#  Row(I94PORT_valid_code='FOR'),
#  Row(I94PORT_valid_code='DOV'),
#  Row(I94PORT_valid_code='EPI'),
#  Row(I94PORT_valid_code='ONT'),
#  Row(I94PORT_valid_code='SNJ'),
#  Row(I94PORT_valid_code='AGS'),
#  Row(I94PORT_valid_code='CHI'),
#  Row(I94PORT_valid_code='FPR'),
#  Row(I94PORT_valid_code='SLI'),
#  Row(I94PORT_valid_code='ANC'),
#  Row(I94PORT_valid_code='DAB'),
#  Row(I94PORT_valid_code='GNV'),
#  Row(I94PORT_valid_code='OGG'),
#  Row(I94PORT_valid_code='DSM'),
#  Row(I94PORT_valid_code='ORL'),
#  Row(I94PORT_valid_code='MAP'),
#  Row(I94PORT_valid_code='ASE'),
#  Row(I94PORT_valid_code='LEE'),
#  Row(I94PORT_valid_code='LEB'),
#  Row(I94PORT_valid_code='INL'),
#  Row(I94PORT_valid_code='HEL'),
#  Row(I94PORT_valid_code='DNS'),
#  Row(I94PORT_valid_code='CRL'),
#  Row(I94PORT_valid_code='HVR'),
#  Row(I94PORT_valid_code='PTK'),
#  Row(I94PORT_valid_code='GTF'),
#  Row(I94PORT_valid_code='MIC'),
#  Row(I94PORT_valid_code='SPM'),
#  Row(I94PORT_valid_code='CAR'),
#  Row(I94PORT_valid_code='SAG'),
#  Row(I94PORT_valid_code='DLB'),
#  Row(I94PORT_valid_code='OSW'),
#  Row(I94PORT_valid_code='GSO'),
#  Row(I94PORT_valid_code='BTM'),
#  Row(I94PORT_valid_code='FAR'),
#  Row(I94PORT_valid_code='ELY'),
#  Row(I94PORT_valid_code='48Y'),
#  Row(I94PORT_valid_code='WAR'),
#  Row(I94PORT_valid_code='CRY'),
#  Row(I94PORT_valid_code='DET'),
#  Row(I94PORT_valid_code='FRT'),
#  Row(I94PORT_valid_code='NOO'),
#  Row(I94PORT_valid_code='REN'),
#  Row(I94PORT_valid_code='HML'),
#  Row(I94PORT_valid_code='PIN'),
#  Row(I94PORT_valid_code='GTR'),
#  Row(I94PORT_valid_code='AGN'),
#  Row(I94PORT_valid_code='SVC'),
#  Row(I94PORT_valid_code='WRI'),
#  Row(I94PORT_valid_code='KAL'),
#  Row(I94PORT_valid_code='CHF'),
#  Row(I94PORT_valid_code='ROS'),
#  Row(I94PORT_valid_code='LAG'),
#  Row(I94PORT_valid_code='AMB'),
#  Row(I94PORT_valid_code='RAY'),
#  Row(I94PORT_valid_code='JER'),
#  Row(I94PORT_valid_code='GPM'),
#  Row(I94PORT_valid_code='CLA'),
#  Row(I94PORT_valid_code='CNJ'),
#  Row(I94PORT_valid_code='WIL'),
#  Row(I94PORT_valid_code='PEM'),
#  Row(I94PORT_valid_code='YIP'),
#  Row(I94PORT_valid_code='SPA'),
#  Row(I94PORT_valid_code='CHM'),
#  Row(I94PORT_valid_code='LVG'),
#  Row(I94PORT_valid_code='HNS'),
#  Row(I94PORT_valid_code='MAG'),
#  Row(I94PORT_valid_code='SSM'),
#  Row(I94PORT_valid_code='CTB'),
#  Row(I94PORT_valid_code='BUF'),
#  Row(I94PORT_valid_code='MOO'),
#  Row(I94PORT_valid_code='POM'),
#  Row(I94PORT_valid_code='WND'),
#  Row(I94PORT_valid_code='LWT'),
#  Row(I94PORT_valid_code='BCY'),
#  Row(I94PORT_valid_code='GRF'),
#  Row(I94PORT_valid_code='SAR'),
#  Row(I94PORT_valid_code='EUR'),
#  Row(I94PORT_valid_code='RNO'),
#  Row(I94PORT_valid_code='FTC'),
#  Row(I94PORT_valid_code='FTK'),
#  Row(I94PORT_valid_code='LUB'),
#  Row(I94PORT_valid_code='RST'),
#  Row(I94PORT_valid_code='GRO'),
#  Row(I94PORT_valid_code='NRG'),
#  Row(I94PORT_valid_code='MRC'),
#  Row(I94PORT_valid_code='WHM'),
#  Row(I94PORT_valid_code='CUT'),
#  Row(I94PORT_valid_code='ANP'),
#  Row(I94PORT_valid_code='SSC'),
#  Row(I94PORT_valid_code='OPH'),
#  Row(I94PORT_valid_code='SCO'),
#  Row(I94PORT_valid_code='LAS'),
#  Row(I94PORT_valid_code='OGD'),
#  Row(I94PORT_valid_code='JAN'),
#  Row(I94PORT_valid_code='CNH'),
#  Row(I94PORT_valid_code='NEC'),
#  Row(I94PORT_valid_code='INT'),
#  Row(I94PORT_valid_code='GRP'),
#  Row(I94PORT_valid_code='MAI'),
#  Row(I94PORT_valid_code='NEW'),
#  Row(I94PORT_valid_code='ALB'),
#  Row(I94PORT_valid_code='MRR'),
#  Row(I94PORT_valid_code='HOB'),
#  Row(I94PORT_valid_code='FOP'),
#  Row(I94PORT_valid_code='LAN'),
#  Row(I94PORT_valid_code='SBR'),
#  Row(I94PORT_valid_code='PAS'),
#  Row(I94PORT_valid_code='PSM'),
#  Row(I94PORT_valid_code='BYO'),
#  Row(I94PORT_valid_code='PER'),
#  Row(I94PORT_valid_code='CLT'),
#  Row(I94PORT_valid_code='SCL'),
#  Row(I94PORT_valid_code='STR'),
#  Row(I94PORT_valid_code='FLX'),
#  Row(I94PORT_valid_code='LIN'),
#  Row(I94PORT_valid_code='PIE'),
#  Row(I94PORT_valid_code='TUR'),
#  Row(I94PORT_valid_code='ABQ'),
#  Row(I94PORT_valid_code='CHT'),
#  Row(I94PORT_valid_code='MRY'),
#  Row(I94PORT_valid_code='DUL'),
#  Row(I94PORT_valid_code='VCB'),
#  Row(I94PORT_valid_code='NIA'),
#  Row(I94PORT_valid_code='SRL'),
#  Row(I94PORT_valid_code='KAN'),
#  Row(I94PORT_valid_code='ALA'),
#  Row(I94PORT_valid_code='NOY'),
#  Row(I94PORT_valid_code='FCA'),
#  Row(I94PORT_valid_code='STL'),
#  Row(I94PORT_valid_code='MHT'),
#  Row(I94PORT_valid_code='FAY'),
#  Row(I94PORT_valid_code='GUL'),
#  Row(I94PORT_valid_code='AXB'),
#  Row(I94PORT_valid_code='WHO'),
#  Row(I94PORT_valid_code='ROO'),
#  Row(I94PORT_valid_code='WSB'),
#  Row(I94PORT_valid_code='MAS'),
#  Row(I94PORT_valid_code='CRA'),
#  Row(I94PORT_valid_code='GGW'),
#  Row(I94PORT_valid_code='WAL'),
#  Row(I94PORT_valid_code='COL'),
#  Row(I94PORT_valid_code='WHI'),
#  Row(I94PORT_valid_code='OMA'),
#  Row(I94PORT_valid_code='MMU'),
#  Row(I94PORT_valid_code='MRH'),
#  Row(I94PORT_valid_code='PNH'),
#  Row(I94PORT_valid_code='RAN'),
#  Row(I94PORT_valid_code='MAD'),
#  Row(I94PORT_valid_code='VNB'),
#  Row(I94PORT_valid_code='SWE'),
#  Row(I94PORT_valid_code='ANT'),
#  Row(I94PORT_valid_code='BIL'),
#  Row(I94PORT_valid_code='SJO'),
#  Row(I94PORT_valid_code='RDU'),
#  Row(I94PORT_valid_code='HTM'),
#  Row(I94PORT_valid_code='HNN'),
#  Row(I94PORT_valid_code='RGM'),
#  Row(I94PORT_valid_code='ACY'),
#  Row(I94PORT_valid_code='TRL'),
#  Row(I94PORT_valid_code='LIM'),
#  Row(I94PORT_valid_code='GPT'),
#  Row(I94PORT_valid_code='MGM'),
#  Row(I94PORT_valid_code='PHU'),
#  Row(I94PORT_valid_code='DNM'),
#  Row(I94PORT_valid_code='JKM'),
#  Row(I94PORT_valid_code='MSP'),
#  Row(I94PORT_valid_code='SGF'),
#  Row(I94PORT_valid_code='CDD'),
#  Row(I94PORT_valid_code='GRE'),
#  Row(I94PORT_valid_code='BZN'),
#  Row(I94PORT_valid_code='LEW'),
#  Row(I94PORT_valid_code='ALP'),
#  Row(I94PORT_valid_code='BAU'),
#  Row(I94PORT_valid_code='WCM'),
#  Row(I94PORT_valid_code='LOB'),
#  Row(I94PORT_valid_code='RBT'),
#  Row(I94PORT_valid_code='RUI'),
#  Row(I94PORT_valid_code='CAP'),
#  Row(I94PORT_valid_code='ISL'),
#  Row(I94PORT_valid_code='SHR'),
#  Row(I94PORT_valid_code='MND'),
#  Row(I94PORT_valid_code='NYC')]

# %%
I94PORT_df = I94PORT_df.withColumn("length", F.length("I94PORT_valid_code"))
I94PORT_df.printSchema()
I94PORT_df.show(truncate=False)
# Out:
# root
#  |-- I94PORT_valid_code: string (nullable = true)
#  |-- I94PORT_valid_value: string (nullable = true)
#  |-- length: integer (nullable = true)
#
# +------------------+-----------------------------+------+
# |I94PORT_valid_code|I94PORT_valid_value          |length|
# +------------------+-----------------------------+------+
# |ORO               |OROVILLE, WA                 |3     |
# |PWB               |PASCO, WA                    |3     |
# |PIR               |POINT ROBERTS, WA            |3     |
# |PNG               |PORT ANGELES, WA             |3     |
# |PTO               |PORT TOWNSEND, WA            |3     |
# |SEA               |SEATTLE, WA                  |3     |
# |SPO               |SPOKANE, WA                  |3     |
# |SUM               |SUMAS, WA                    |3     |
# |TAC               |TACOMA, WA                   |3     |
# |PSC               |TRI-CITIES - PASCO, WA       |3     |
# |VAN               |VANCOUVER, WA                |3     |
# |AGM               |ALGOMA, WI                   |3     |
# |BAY               |BAYFIELD, WI                 |3     |
# |GRB               |GREEN BAY, WI                |3     |
# |MNW               |MANITOWOC, WI                |3     |
# |MIL               |MILWAUKEE, WI                |3     |
# |MSN               |TRUAX FIELD - DANE COUNTY, WI|3     |
# |CHS               |CHARLESTON, WV               |3     |
# |CLK               |CLARKSBURG, WV               |3     |
# |BLF               |MERCER COUNTY, WV            |3     |
# +------------------+-----------------------------+------+
# only showing top 20 rows

# %%
# Create table from dataframe
I94PORT_df.createOrReplaceTempView('i94ports_table')

# %%
# Verify created table will be using for staging
spark.sql("""
    SELECT COUNT(*) as amount_i94ports_rows
    FROM i94ports_table
""").show()
# Out:
# +--------------------+
# |amount_i94ports_rows|
# +--------------------+
# |                 660|
# +--------------------+

# %% [markdown]
# ### `I94ADDR` label - Extract and staging validation values from 'SAS_Labels_Descriptions.SAS'

# %%
I94ADDR_df = extract_staging_sas_label('I94ADDR')
# Out:
# Top 20 rows of I94ADDR_sas_label_validation
# +------------------+-------------------+
# |I94ADDR_valid_code|I94ADDR_valid_value|
# +------------------+-------------------+
# |                PA|       PENNSYLVANIA|
# |                PR|        PUERTO RICO|
# |                RI|       RHODE ISLAND|
# |                SC|        S. CAROLINA|
# |                SD|          S. DAKOTA|
# |                TN|          TENNESSEE|
# |                TX|              TEXAS|
# |                UT|               UTAH|
# |                VT|            VERMONT|
# |                VI|     VIRGIN ISLANDS|
# |                VA|           VIRGINIA|
# |                WV|        W. VIRGINIA|
# |                WA|         WASHINGTON|
# |                WI|          WISCONSON|
# |                WY|            WYOMING|
# |                99|    All Other Codes|
# |                MO|           MISSOURI|
# |                MT|            MONTANA|
# |                NC|        N. CAROLINA|
# |                ND|          N. DAKOTA|
# +------------------+-------------------+
# only showing top 20 rows
#
# Count rows of I94ADDR_sas_label_validation: 55
# Check unique value of I94ADDR_sas_label_validation: 55
# Staging csv files in: I94ADDR_sas_label_validation

# %%
I94ADDR_df.select('I94ADDR_valid_code').distinct().collect()
# Out:
# [Row(I94ADDR_valid_code='SC'),
#  Row(I94ADDR_valid_code='99'),
#  Row(I94ADDR_valid_code='VA'),
#  Row(I94ADDR_valid_code='RI'),
#  Row(I94ADDR_valid_code='WY'),
#  Row(I94ADDR_valid_code='WI'),
#  Row(I94ADDR_valid_code='VT'),
#  Row(I94ADDR_valid_code='VI'),
#  Row(I94ADDR_valid_code='WA'),
#  Row(I94ADDR_valid_code='TN'),
#  Row(I94ADDR_valid_code='PA'),
#  Row(I94ADDR_valid_code='SD'),
#  Row(I94ADDR_valid_code='TX'),
#  Row(I94ADDR_valid_code='WV'),
#  Row(I94ADDR_valid_code='PR'),
#  Row(I94ADDR_valid_code='UT'),
#  Row(I94ADDR_valid_code='NJ'),
#  Row(I94ADDR_valid_code='OR'),
#  Row(I94ADDR_valid_code='NH'),
#  Row(I94ADDR_valid_code='NV'),
#  Row(I94ADDR_valid_code='NE'),
#  Row(I94ADDR_valid_code='MT'),
#  Row(I94ADDR_valid_code='NC'),
#  Row(I94ADDR_valid_code='MO'),
#  Row(I94ADDR_valid_code='ND'),
#  Row(I94ADDR_valid_code='OH'),
#  Row(I94ADDR_valid_code='NM'),
#  Row(I94ADDR_valid_code='NY'),
#  Row(I94ADDR_valid_code='OK'),
#  Row(I94ADDR_valid_code='AZ'),
#  Row(I94ADDR_valid_code='DC'),
#  Row(I94ADDR_valid_code='CA'),
#  Row(I94ADDR_valid_code='CT'),
#  Row(I94ADDR_valid_code='DE'),
#  Row(I94ADDR_valid_code='GU'),
#  Row(I94ADDR_valid_code='AL'),
#  Row(I94ADDR_valid_code='GA'),
#  Row(I94ADDR_valid_code='CO'),
#  Row(I94ADDR_valid_code='FL'),
#  Row(I94ADDR_valid_code='AK'),
#  Row(I94ADDR_valid_code='AR'),
#  Row(I94ADDR_valid_code='HI'),
#  Row(I94ADDR_valid_code='LA'),
#  Row(I94ADDR_valid_code='MN'),
#  Row(I94ADDR_valid_code='KY'),
#  Row(I94ADDR_valid_code='MI'),
#  Row(I94ADDR_valid_code='ID'),
#  Row(I94ADDR_valid_code='MD'),
#  Row(I94ADDR_valid_code='IL'),
#  Row(I94ADDR_valid_code='ME'),
#  Row(I94ADDR_valid_code='MS'),
#  Row(I94ADDR_valid_code='IN'),
#  Row(I94ADDR_valid_code='IA'),
#  Row(I94ADDR_valid_code='MA'),
#  Row(I94ADDR_valid_code='KS')]

# %%
I94ADDR_df = I94ADDR_df.withColumn("length", F.length("I94ADDR_valid_code"))
I94ADDR_df.printSchema()
I94ADDR_df.show(truncate=False)
# Out:
# root
#  |-- I94ADDR_valid_code: string (nullable = true)
#  |-- I94ADDR_valid_value: string (nullable = true)
#  |-- length: integer (nullable = true)
#
# +------------------+-------------------+------+
# |I94ADDR_valid_code|I94ADDR_valid_value|length|
# +------------------+-------------------+------+
# |PA                |PENNSYLVANIA       |2     |
# |PR                |PUERTO RICO        |2     |
# |RI                |RHODE ISLAND       |2     |
# |SC                |S. CAROLINA        |2     |
# |SD                |S. DAKOTA          |2     |
# |TN                |TENNESSEE          |2     |
# |TX                |TEXAS              |2     |
# |UT                |UTAH               |2     |
# |VT                |VERMONT            |2     |
# |VI                |VIRGIN ISLANDS     |2     |
# |VA                |VIRGINIA           |2     |
# |WV                |W. VIRGINIA        |2     |
# |WA                |WASHINGTON         |2     |
# |WI                |WISCONSON          |2     |
# |WY                |WYOMING            |2     |
# |99                |All Other Codes    |2     |
# |MO                |MISSOURI           |2     |
# |MT                |MONTANA            |2     |
# |NC                |N. CAROLINA        |2     |
# |ND                |N. DAKOTA          |2     |
# +------------------+-------------------+------+
# only showing top 20 rows

# %%
# Create table from dataframe
I94ADDR_df.createOrReplaceTempView('i94addr_table')

# %%
# Verify created table will be using for staging
spark.sql("""
        SELECT COUNT(*) as amount_i94addr_rows
        FROM i94addr_table
""").show()
# Out:
# +-------------------+
# |amount_i94addr_rows|
# +-------------------+
# |                 55|
# +-------------------+

# %% [markdown]
# ### `I94MODE` label - Extract and staging validation values from 'SAS_Labels_Descriptions.SAS'

# %%
I94MODE_df = extract_staging_sas_label('I94MODE')
# Out:
# Top 20 rows of I94MODE_sas_label_validation
# +------------------+-------------------+
# |I94MODE_valid_code|I94MODE_valid_value|
# +------------------+-------------------+
# |                 9|       Not reported|
# |                 3|               Land|
# |                 1|                Air|
# |                 2|                Sea|
# +------------------+-------------------+
#
# Count rows of I94MODE_sas_label_validation: 4
# Check unique value of I94MODE_sas_label_validation: 4
# Staging csv files in: I94MODE_sas_label_validation

# %%
I94MODE_df.select('I94MODE_valid_code').distinct().collect()
# Out:
# [Row(I94MODE_valid_code=9),
#  Row(I94MODE_valid_code=3),
#  Row(I94MODE_valid_code=1),
#  Row(I94MODE_valid_code=2)]

# %%
I94MODE_df = I94MODE_df.withColumn("length", F.length("I94MODE_valid_code"))
I94MODE_df.printSchema()
I94MODE_df.show(truncate=False)
# Out:
# root
#  |-- I94MODE_valid_code: integer (nullable = true)
#  |-- I94MODE_valid_value: string (nullable = true)
#  |-- length: integer (nullable = true)
#
# +------------------+-------------------+------+
# |I94MODE_valid_code|I94MODE_valid_value|length|
# +------------------+-------------------+------+
# |9                 |Not reported       |1     |
# |3                 |Land               |1     |
# |1                 |Air                |1     |
# |2                 |Sea                |1     |
# +------------------+-------------------+------+

# %%
# Create table from dataframe
I94MODE_df.createOrReplaceTempView('i94mode_table')

# %%
# Verify created table will be using for staging
spark.sql("""
    SELECT COUNT(*) as amount_i94mode_rows
    FROM i94mode_table
""").show()
# Out:
# +-------------------+
# |amount_i94mode_rows|
# +-------------------+
# |                  4|
# +-------------------+

# %% [markdown]
# ### `I94VISA` label - Extract and staging validation values from 'SAS_Labels_Descriptions.SAS'

# %%
I94VISA_df = extract_staging_sas_label('I94VISA')
# Out:
# Top 20 rows of I94VISA_sas_label_validation
# +------------------+-------------------+
# |I94VISA_valid_code|I94VISA_valid_value|
# +------------------+-------------------+
# |                 1|           Business|
# |                 2|           Pleasure|
# |                 3|            Student|
# +------------------+-------------------+
#
# Count rows of I94VISA_sas_label_validation: 3
# Check unique value of I94VISA_sas_label_validation: 3
# Staging csv files in: I94VISA_sas_label_validation

# %%
I94VISA_df.select('I94VISA_valid_code').distinct().collect()
# Out:
# [Row(I94VISA_valid_code=1),
#  Row(I94VISA_valid_code=2),
#  Row(I94VISA_valid_code=3)]

# %%
I94VISA_df = I94VISA_df.withColumn("length", F.length("I94VISA_valid_code"))
I94VISA_df.printSchema()
I94VISA_df.show(truncate=False)
# Out:
# root
#  |-- I94VISA_valid_code: integer (nullable = true)
#  |-- I94VISA_valid_value: string (nullable = true)
#  |-- length: integer (nullable = true)
#
# +------------------+-------------------+------+
# |I94VISA_valid_code|I94VISA_valid_value|length|
# +------------------+-------------------+------+
# |1                 |Business           |1     |
# |2                 |Pleasure           |1     |
# |3                 |Student            |1     |
# +------------------+-------------------+------+

# %%
# Create table from dataframe
I94VISA_df.createOrReplaceTempView('i94visa_table')

# %%
# Verify created table will be using for staging
spark.sql("""
    SELECT COUNT(*) as amount_i94visa_rows
    FROM i94visa_table
""").show()
# Out:
# +-------------------+
# |amount_i94visa_rows|
# +-------------------+
# |                  3|
# +-------------------+
